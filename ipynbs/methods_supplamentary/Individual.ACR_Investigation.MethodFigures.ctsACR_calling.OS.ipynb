# %%
library("devtools")
library("tidyverse")
# Out:
# Warning message:
# “package ‘devtools’ was built under R version 4.3.1”
# Loading required package: usethis
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2          ✔ readr     2.1.4
# ✔ forcats   1.0.0.9000     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.3          ✔ tibble    3.2.1
# ✔ lubridate 1.9.2          ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
zm_all_data <- readRDS("/scratch/jpm73279/comparative_single_cell/07.call.ACRs/03.peak_assignment/os_dir/os_acr_classification.no_exons.combined_data.rds")

# %%
zm_all_pvalues <- read_delim("/scratch/jpm73279/comparative_single_cell/07.call.ACRs/03.peak_assignment/os_dir/os_acr_classification.no_exons.all_pvalues.csv", delim = ",")
# Out:
# Rows: 438683 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): ACR_values, cell_type
# dbl (5): perm_pval, perm_pval_lower, perm_pval_upper, pnorm_pval, z_score
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
glimpse(zm_all_data)
# Out:
# Rows: 438,683
# Columns: 16
# $ ACR_values          <chr> "scACR_1", "scACR_1", "scACR_1", "scACR_1", "scACR…
# $ cell_type           <chr> "bundle_sheath", "companion_cell", "epidermis", "m…
# $ distribution        <list> [<tbl_df[2000 x 1]>], [<tbl_df[2000 x 1]>], [<tbl…
# $ null_dist           <list> [<tbl_df[28000 x 1]>], [<tbl_df[28000 x 1]>], [<t…
# $ list_len            <dbl> 28001, 28001, 28001, 28001, 28001, 28001, 28001, 2…
# $ median_val          <dbl> 6.080003, 4.114822, 6.504683, 5.842573, 5.000849, …
# $ conf_interval_lower <dbl> 5.541390, 3.605381, 6.057118, 5.420734, 4.347297, …
# $ conf_interval_upper <dbl> 6.618036, 4.644064, 6.998973, 6.295611, 5.683035, …
# $ med_val_perm        <int> 24363, 3, 27681, 19688, 1938, 27208, 7293, 14781, …
# $ perm_pval           <dbl> 0.870076069, 0.000107139, 0.988571837, 0.703117746…
# $ perm_pval_lower     <dbl> 0.4280204278, 0.0000000000, 0.8573979501, 0.318381…
# $ perm_pval_upper     <dbl> 0.995357309, 0.009213957, 0.999928574, 0.953894504…
# $ null_dist_mean      <dbl> 5.615133, 5.615133, 5.615133, 5.615133, 5.615133, …
# $ null_dist_sd        <dbl> 0.4093987, 0.4093987, 0.4093987, 0.4093987, 0.4093…
# $ pnorm_pval          <dbl> 0.8719160519, 0.0001238293, 0.9851031003, 0.710739…
# $ z_score             <dbl> 1.13549519, -3.66466902, 2.17282090, 0.55554775, -…

# %%
# options(repr.plot.width=15, repr.plot.height=15)
# #Bad looking on browser - edge of Sig
# look_group <- c("scACR_4671", "scACR_13067", "scACR_14828")
# plot_acr_null_real <- zm_all_data %>% 
#     ungroup() %>% 
#     dplyr::filter(ACR_values %in% look_group)

# %%
glimpse(zm_all_data)
# Out:
# Rows: 438,683
# Columns: 16
# $ ACR_values          <chr> "scACR_1", "scACR_1", "scACR_1", "scACR_1", "scACR…
# $ cell_type           <chr> "bundle_sheath", "companion_cell", "epidermis", "m…
# $ distribution        <list> [<tbl_df[2000 x 1]>], [<tbl_df[2000 x 1]>], [<tbl…
# $ null_dist           <list> [<tbl_df[28000 x 1]>], [<tbl_df[28000 x 1]>], [<t…
# $ list_len            <dbl> 28001, 28001, 28001, 28001, 28001, 28001, 28001, 2…
# $ median_val          <dbl> 6.080003, 4.114822, 6.504683, 5.842573, 5.000849, …
# $ conf_interval_lower <dbl> 5.541390, 3.605381, 6.057118, 5.420734, 4.347297, …
# $ conf_interval_upper <dbl> 6.618036, 4.644064, 6.998973, 6.295611, 5.683035, …
# $ med_val_perm        <int> 24363, 3, 27681, 19688, 1938, 27208, 7293, 14781, …
# $ perm_pval           <dbl> 0.870076069, 0.000107139, 0.988571837, 0.703117746…
# $ perm_pval_lower     <dbl> 0.4280204278, 0.0000000000, 0.8573979501, 0.318381…
# $ perm_pval_upper     <dbl> 0.995357309, 0.009213957, 0.999928574, 0.953894504…
# $ null_dist_mean      <dbl> 5.615133, 5.615133, 5.615133, 5.615133, 5.615133, …
# $ null_dist_sd        <dbl> 0.4093987, 0.4093987, 0.4093987, 0.4093987, 0.4093…
# $ pnorm_pval          <dbl> 0.8719160519, 0.0001238293, 0.9851031003, 0.710739…
# $ z_score             <dbl> 1.13549519, -3.66466902, 2.17282090, 0.55554775, -…

# %%
## Generate the same plot looking at ACRs associated with marker genes 
options(repr.plot.width=15, repr.plot.height=15)
#Bad looking on browser - edge of Sig
# MS MS BS 
look_group <- c("scACR_27047", "scACR_1719", "scACR_49825", "scACR_38596")
plot_acr_null_real <- zm_all_data %>% 
    ungroup() %>% 
    dplyr::filter(ACR_values %in% look_group) %>% 
    dplyr::filter(cell_type %in% c("epidermis",  "bundle_sheath", "mesophyll")) %>% 
    mutate(ACR_values = factor(ACR_values, levels = look_group)) %>%  # Reorder the levels of ACR_values
    unnest(distribution) %>% 
    rename(real_value = value) %>% 
    mutate(null_dist = lapply(null_dist, function(x) x %>% sample_n(5000))) %>% # Subsampling 5000 entries
    unnest(null_dist)%>% 
    rename(null_value = value) %>% 
    pivot_longer(c(real_value, null_value), names_to = "class", values_to = "val")

# %%
library(cowplot)
library(patchwork)
# Out:
# Attaching package: ‘cowplot’
#
#
# The following object is masked from ‘package:lubridate’:
#
#     stamp
#
#
#
# Attaching package: ‘patchwork’
#
#
# The following object is masked from ‘package:cowplot’:
#
#     align_plots

# %%
plot_acr_null_real
# Out:
#           ACR_values  cell_type     list_len median_val conf_interval_lower
# 1         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 2         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 3         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 4         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 5         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 6         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 7         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 8         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 9         scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 10        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 11        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 12        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 13        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 14        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 15        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 16        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 17        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 18        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 19        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 20        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 21        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 22        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 23        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 24        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 25        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 26        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 27        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 28        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 29        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# 30        scACR_1719  bundle_sheath 28001    4.681066   4.30929
# ⋮         ⋮           ⋮             ⋮        ⋮          ⋮
# 239999971 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999972 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999973 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999974 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999975 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999976 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999977 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999978 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999979 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999980 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999981 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999982 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999983 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999984 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999985 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999986 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999987 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999988 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999989 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999990 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999991 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999992 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999993 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999994 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999995 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999996 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999997 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999998 scACR_49825 mesophyll     28001    5.602946   5.337373
# 239999999 scACR_49825 mesophyll     28001    5.602946   5.337373
# 240000000 scACR_49825 mesophyll     28001    5.602946   5.337373
#           conf_interval_upper med_val_perm perm_pval    perm_pval_lower
# 1         5.107901            21           0.0007499732 0
# 2         5.107901            21           0.0007499732 0
# 3         5.107901            21           0.0007499732 0
# 4         5.107901            21           0.0007499732 0
# 5         5.107901            21           0.0007499732 0
# 6         5.107901            21           0.0007499732 0
# 7         5.107901            21           0.0007499732 0
# 8         5.107901            21           0.0007499732 0
# 9         5.107901            21           0.0007499732 0
# 10        5.107901            21           0.0007499732 0
# 11        5.107901            21           0.0007499732 0
# 12        5.107901            21           0.0007499732 0
# 13        5.107901            21           0.0007499732 0
# 14        5.107901            21           0.0007499732 0
# 15        5.107901            21           0.0007499732 0
# 16        5.107901            21           0.0007499732 0
# 17        5.107901            21           0.0007499732 0
# 18        5.107901            21           0.0007499732 0
# 19        5.107901            21           0.0007499732 0
# 20        5.107901            21           0.0007499732 0
# 21        5.107901            21           0.0007499732 0
# 22        5.107901            21           0.0007499732 0
# 23        5.107901            21           0.0007499732 0
# 24        5.107901            21           0.0007499732 0
# 25        5.107901            21           0.0007499732 0
# 26        5.107901            21           0.0007499732 0
# 27        5.107901            21           0.0007499732 0
# 28        5.107901            21           0.0007499732 0
# 29        5.107901            21           0.0007499732 0
# 30        5.107901            21           0.0007499732 0
# ⋮         ⋮                   ⋮            ⋮            ⋮
# 239999971 5.894907            14017        0.5005893    0.2521696
# 239999972 5.894907            14017        0.5005893    0.2521696
# 239999973 5.894907            14017        0.5005893    0.2521696
# 239999974 5.894907            14017        0.5005893    0.2521696
# 239999975 5.894907            14017        0.5005893    0.2521696
# 239999976 5.894907            14017        0.5005893    0.2521696
# 239999977 5.894907            14017        0.5005893    0.2521696
# 239999978 5.894907            14017        0.5005893    0.2521696
# 239999979 5.894907            14017        0.5005893    0.2521696
# 239999980 5.894907            14017        0.5005893    0.2521696
# 239999981 5.894907            14017        0.5005893    0.2521696
# 239999982 5.894907            14017        0.5005893    0.2521696
# 239999983 5.894907            14017        0.5005893    0.2521696
# 239999984 5.894907            14017        0.5005893    0.2521696
# 239999985 5.894907            14017        0.5005893    0.2521696
# 239999986 5.894907            14017        0.5005893    0.2521696
# 239999987 5.894907            14017        0.5005893    0.2521696
# 239999988 5.894907            14017        0.5005893    0.2521696
# 239999989 5.894907            14017        0.5005893    0.2521696
# 239999990 5.894907            14017        0.5005893    0.2521696
# 239999991 5.894907            14017        0.5005893    0.2521696
# 239999992 5.894907            14017        0.5005893    0.2521696
# 239999993 5.894907            14017        0.5005893    0.2521696
# 239999994 5.894907            14017        0.5005893    0.2521696
# 239999995 5.894907            14017        0.5005893    0.2521696
# 239999996 5.894907            14017        0.5005893    0.2521696
# 239999997 5.894907            14017        0.5005893    0.2521696
# 239999998 5.894907            14017        0.5005893    0.2521696
# 239999999 5.894907            14017        0.5005893    0.2521696
# 240000000 5.894907            14017        0.5005893    0.2521696
#           perm_pval_upper null_dist_mean null_dist_sd pnorm_pval  z_score
# 1         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 2         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 3         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 4         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 5         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 6         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 7         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 8         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 9         0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 10        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 11        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 12        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 13        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 14        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 15        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 16        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 17        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 18        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 19        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 20        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 21        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 22        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 23        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 24        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 25        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 26        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 27        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 28        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 29        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# 30        0.04931967      5.615505       0.3205468    0.001777642 -2.915141
# ⋮         ⋮               ⋮              ⋮            ⋮           ⋮
# 239999971 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999972 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999973 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999974 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999975 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999976 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999977 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999978 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999979 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999980 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999981 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999982 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999983 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999984 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999985 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999986 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999987 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999988 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999989 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999990 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999991 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999992 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999993 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999994 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999995 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999996 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999997 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999998 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 239999999 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
# 240000000 0.7559016       5.61636        0.4139466    0.4870741   -0.03240611
#           class      val
# 1         real_value 4.494260
# 2         null_value 5.272172
# 3         real_value 4.494260
# 4         null_value 5.348278
# 5         real_value 4.494260
# 6         null_value 5.944155
# 7         real_value 4.494260
# 8         null_value 5.569920
# 9         real_value 4.494260
# 10        null_value 5.251088
# 11        real_value 4.494260
# 12        null_value 5.419330
# 13        real_value 4.494260
# 14        null_value 5.768313
# 15        real_value 4.494260
# 16        null_value 5.255017
# 17        real_value 4.494260
# 18        null_value 5.837997
# 19        real_value 4.494260
# 20        null_value 5.478879
# 21        real_value 4.494260
# 22        null_value 5.507257
# 23        real_value 4.494260
# 24        null_value 4.901467
# 25        real_value 4.494260
# 26        null_value 5.615320
# 27        real_value 4.494260
# 28        null_value 5.994049
# 29        real_value 4.494260
# 30        null_value 5.760432
# ⋮         ⋮          ⋮
# 239999971 real_value 5.673437
# 239999972 null_value 5.434000
# 239999973 real_value 5.673437
# 239999974 null_value 5.624177
# 239999975 real_value 5.673437
# 239999976 null_value 5.251273
# 239999977 real_value 5.673437
# 239999978 null_value 5.555143
# 239999979 real_value 5.673437
# 239999980 null_value 5.277598
# 239999981 real_value 5.673437
# 239999982 null_value 5.583720
# 239999983 real_value 5.673437
# 239999984 null_value 6.031919
# 239999985 real_value 5.673437
# 239999986 null_value 5.077324
# 239999987 real_value 5.673437
# 239999988 null_value 5.697842
# 239999989 real_value 5.673437
# 239999990 null_value 5.380199
# 239999991 real_value 5.673437
# 239999992 null_value 5.200458
# 239999993 real_value 5.673437
# 239999994 null_value 5.660585
# 239999995 real_value 5.673437
# 239999996 null_value 6.548645
# 239999997 real_value 5.673437
# 239999998 null_value 5.269926
# 239999999 real_value 5.673437
# 240000000 null_value 5.867092

# %%
acr_meds <- plot_acr_null_real %>% 
    group_by(class, cell_type, ACR_values) %>% 
    summarise(median_val = mean(val))
 
ggplot(plot_acr_null_real, aes(val, color = class)) + geom_density() + geom_density(alpha = 0.1) + 
    facet_grid(ACR_values~cell_type, scales="free_y") +
      geom_vline(data=acr_meds, aes(xintercept=median_val, color=class),
             linetype="dashed")
# Out:
# `summarise()` has grouped output by 'class', 'cell_type'. You can override
# using the `.groups` argument.
# plot without title

# %%
head(plot_acr_null_real)
# Out:
#   ACR_values cell_type     list_len median_val conf_interval_lower
# 1 scACR_5314 bundle_sheath 29989    4.637389   4.063287
# 2 scACR_5314 bundle_sheath 29989    4.637389   4.063287
# 3 scACR_5314 bundle_sheath 29989    4.637389   4.063287
# 4 scACR_5314 bundle_sheath 29989    4.637389   4.063287
# 5 scACR_5314 bundle_sheath 29989    4.637389   4.063287
# 6 scACR_5314 bundle_sheath 29989    4.637389   4.063287
#   conf_interval_upper med_val_perm perm_pval perm_pval_lower perm_pval_upper
# 1 5.193995            6097         0.2033079 0.07596119      0.4195872
# 2 5.193995            6097         0.2033079 0.07596119      0.4195872
# 3 5.193995            6097         0.2033079 0.07596119      0.4195872
# 4 5.193995            6097         0.2033079 0.07596119      0.4195872
# 5 5.193995            6097         0.2033079 0.07596119      0.4195872
# 6 5.193995            6097         0.2033079 0.07596119      0.4195872
#   null_dist_mean null_dist_sd pnorm_pval z_score    class      val
# 1 5.161437       0.663033     0.2146529  -0.7903801 real_value 4.468701
# 2 5.161437       0.663033     0.2146529  -0.7903801 null_value 3.946755
# 3 5.161437       0.663033     0.2146529  -0.7903801 real_value 4.468701
# 4 5.161437       0.663033     0.2146529  -0.7903801 null_value 4.954220
# 5 5.161437       0.663033     0.2146529  -0.7903801 real_value 4.468701
# 6 5.161437       0.663033     0.2146529  -0.7903801 null_value 5.819600

# %%
subset <- plot_acr_null_real %>% 
    dplyr::select(ACR_values, cell_type,z_score) %>% 
    dplyr::distinct()

# %%
pnorm(-1.7782268, lower.tail = TRUE)
# Out:
# [1] 0.03768331

# %%
subset
# Out:
#   ACR_values cell_type     z_score
# 1 scACR_5314 bundle_sheath -0.7903801
# 2 scACR_5314 epidermis      0.8779177
# 3 scACR_5314 mesophyll      0.6859526
# 4 scACR_5316 bundle_sheath  0.7067251
# 5 scACR_5316 epidermis      0.4719163
# 6 scACR_5316 mesophyll     -1.7782268
# 7 scACR_5317 bundle_sheath  0.4298118
# 8 scACR_5317 epidermis      0.3478216
# 9 scACR_5317 mesophyll     -1.0582585

# %%
#Broadly ACC ACRs
## Generate the same plot looking at ACRs associated with marker genes 
options(repr.plot.width=15, repr.plot.height=15)
#Bad looking on browser - edge of Sig
#look_group <- c("scACR_726", "scACR_899", "scACR_52688")
look_group <- c("scACR_5316", "scACR_5317", "scACR_5314")

plot_acr_null_real <- zm_all_data %>% 
    ungroup() %>% 
    dplyr::filter(ACR_values %in% look_group) %>% 
    dplyr::filter(cell_type %in% c("epidermis", "companion_cells_sieve_elements", "bundle_sheath", "mesophyll")) %>% 
    mutate(ACR_values = factor(ACR_values, levels = look_group)) %>%  # Reorder the levels of ACR_values
    unnest(distribution) %>% 
    rename(real_value = value) %>% 
    unnest(null_dist)%>% 
    rename(null_value = value) %>% 
    pivot_longer(c(real_value,null_value), names_to = "class", values_to = "val") 

acr_meds <- plot_acr_null_real %>% 
    group_by(class, cell_type, ACR_values) %>% 
    summarise(median_val = mean(val))
 
ggplot(plot_acr_null_real, aes(val, color = class)) + geom_density() + facet_grid(ACR_values~cell_type, scales="free_y") +
      geom_vline(data=acr_meds, aes(xintercept=median_val, color=class),
             linetype="dashed")

# %%
acr_meds
# Out:
#    class      cell_type                      ACR_values median_val
# 1  null_value bundle_sheath                  scACR_4671 5.175151
# 2  null_value bundle_sheath                  scACR_4670 5.160342
# 3  null_value bundle_sheath                  scACR_5927 5.164167
# 4  null_value companion_cells_sieve_elements scACR_4671 5.175151
# 5  null_value companion_cells_sieve_elements scACR_4670 5.160342
# 6  null_value companion_cells_sieve_elements scACR_5927 5.164167
# 7  null_value epidermis                      scACR_4671 5.175151
# 8  null_value epidermis                      scACR_4670 5.160342
# 9  null_value epidermis                      scACR_5927 5.164167
# 10 null_value mesophyll                      scACR_4671 5.175151
# 11 null_value mesophyll                      scACR_4670 5.160342
# 12 null_value mesophyll                      scACR_5927 5.164167
# 13 real_value bundle_sheath                  scACR_4671 3.402217
# 14 real_value bundle_sheath                  scACR_4670 3.444895
# 15 real_value bundle_sheath                  scACR_5927 5.113272
# 16 real_value companion_cells_sieve_elements scACR_4671 6.181042
# 17 real_value companion_cells_sieve_elements scACR_4670 5.631358
# 18 real_value companion_cells_sieve_elements scACR_5927 5.412683
# 19 real_value epidermis                      scACR_4671 6.012032
# 20 real_value epidermis                      scACR_4670 5.664136
# 21 real_value epidermis                      scACR_5927 5.402608
# 22 real_value mesophyll                      scACR_4671 6.250727
# 23 real_value mesophyll                      scACR_4670 5.648513
# 24 real_value mesophyll                      scACR_5927 4.278394

# %%
glimpse(plot_acr_null_real)
# Out:
# Rows: 568,848,000
# Columns: 16
# $ ACR_values          <fct> scACR_4670, scACR_4670, scACR_4670, scACR_4670, sc…
# $ cell_type           <chr> "bundle_sheath", "bundle_sheath", "bundle_sheath",…
# $ list_len            <dbl> 23947, 23947, 23947, 23947, 23947, 23947, 23947, 2…
# $ median_val          <dbl> 3.444895, 3.444895, 3.444895, 3.444895, 3.444895, …
# $ conf_interval_lower <dbl> 2.813012, 2.813012, 2.813012, 2.813012, 2.813012, …
# $ conf_interval_upper <dbl> 4.069715, 4.069715, 4.069715, 4.069715, 4.069715, …
# $ med_val_perm        <int> 401, 401, 401, 401, 401, 401, 401, 401, 401, 401, …
# $ perm_pval           <dbl> 0.01674531, 0.01674531, 0.01674531, 0.01674531, 0.…
# $ perm_pval_lower     <dbl> 0.001920909, 0.001920909, 0.001920909, 0.001920909…
# $ perm_pval_upper     <dbl> 0.06919447, 0.06919447, 0.06919447, 0.06919447, 0.…
# $ null_dist_mean      <dbl> 5.160342, 5.160342, 5.160342, 5.160342, 5.160342, …
# $ null_dist_sd        <dbl> 0.6241811, 0.6241811, 0.6241811, 0.6241811, 0.6241…
# $ pnorm_pval          <dbl> 0.002995109, 0.002995109, 0.002995109, 0.002995109…
# $ z_score             <dbl> -2.748316, -2.748316, -2.748316, -2.748316, -2.748…
# $ class               <chr> "real_value", "null_value", "real_value", "null_va…
# $ val                 <dbl> 3.871676, 5.207050, 3.871676, 5.228408, 3.871676, …

# %%
library(cowplot)

brroadly_accessible_ACRs <- ggplot(plot_acr_null_real, aes(val, color = class)) + geom_density(alpha = 0.1) + facet_grid(ACR_values~cell_type, scales="free_y") +
      geom_vline(data=acr_meds, aes(xintercept=median_val, color=class),
             linetype="dashed") + theme_half_open() + panel_border()

# %%
#options(repr.plot.width=15, repr.plot.height=10)
#brroadly_accessible_ACRs
ggsave(filename = "/home/jpm73279/data_copy_over/comparative_single_cell_imgs/gordon_conference/broadly_acc_ACRs.pdf", plot = brroadly_accessible_ACRs, device = "pdf", width = 15, height = 10)

# %%
ggsave(filename = "/home/jpm73279/data_copy_over/comparative_single_cell_imgs/gordon_conference/cell_type_specific.ACRs.pdf", plot = cell_type_specific_plots, device = "pdf", width = 15, height = 15)
